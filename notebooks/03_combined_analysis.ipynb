# %% [markdown]
# # Combined Energy Market Analysis
#
# This notebook provides comprehensive analysis combining ENTSO-E and EPEX data.
#
# For detailed analysis, see:
# - 01_entsoe_data_analysis.ipynb
# - 02_epex_spot_analysis.ipynb
